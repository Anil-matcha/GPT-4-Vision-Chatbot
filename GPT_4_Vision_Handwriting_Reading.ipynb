# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil-matcha/GPT-4-Vision-Chatbot/blob/main/GPT_4_Vision_Handwriting_Reading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "openai>=1"
# Out:
# Collecting openai>=1
#   Downloading openai-1.1.1-py3-none-any.whl (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1) (1.10.13)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai>=1) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai>=1) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai>=1) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai>=1) (1.1.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1) (2023.7.22)
# Collecting httpcore (from httpx<1,>=0.23.0->openai>=1)
#   Downloading httpcore-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.9 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore->httpx<1,>=0.23.0->openai>=1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed h11-0.14.0 httpcore-1.0.1 httpx-0.25.1 openai-1.1.1

# %%
import cv2
from google.colab.patches import cv2_imshow
# !wget https://assets-global.website-files.com/624ac40503a527cf47af4192/646dc5b7fb9da46acab64901_handwrited.jpeg
img = cv2.imread("646dc5b7fb9da46acab64901_handwrited.jpeg")
cv2_imshow(img)
# Out:
# --2023-11-07 14:52:49--  https://assets-global.website-files.com/624ac40503a527cf47af4192/646dc5b7fb9da46acab64901_handwrited.jpeg
# Resolving assets-global.website-files.com (assets-global.website-files.com)... 18.67.65.118, 18.67.65.38, 18.67.65.111, ...
# Connecting to assets-global.website-files.com (assets-global.website-files.com)|18.67.65.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43563 (43K) [image/jpeg]
# Saving to: ‘646dc5b7fb9da46acab64901_handwrited.jpeg’
#
# 646dc5b7fb9da46acab 100%[===================>]  42.54K  --.-KB/s    in 0s
#
# 2023-11-07 14:52:49 (259 MB/s) - ‘646dc5b7fb9da46acab64901_handwrited.jpeg’ saved [43563/43563]
# <PIL.Image.Image image mode=RGB size=730x514>

# %%
import os
os.environ["OPENAI_API_KEY"] = "openai-key"
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4-vision-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Can you read this ?"},
                {
                    "type": "image_url",
                    "image_url": "https://assets-global.website-files.com/624ac40503a527cf47af4192/646dc5b7fb9da46acab64901_handwrited.jpeg",
                },
            ],
        },
    ],
    max_tokens=1000,
)

# %%
out = response.choices[0].message.content
print(out)
# Out:
# Yes, I can read the text in the image. It says:
#
# Hello,
# Simply Noted has developed incredible proprietary robotic technology to write your message and envelopes with a genuine real pen. It is completely indistinguishable from a humans handwriting.
# Try us today!
# Simply Noted
